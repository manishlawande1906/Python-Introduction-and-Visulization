# %% [markdown]
# # Python Introduction and Visulization

# %%
import pandas as pd
df = pd.read_csv("Salaries.csv")
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.head()        ##it shows first 5 rows
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()       ##it shows last 5 rows
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.head(8)                ##it shows first 8 rows
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300

# %%
df.dtypes              ##pandas datatypes names are diff. so it shown object
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.salary.mean()
# Out:
# 108023.78205128205

# %%
df.service.max()
# Out:
# 51

# %%
df.phd.std()
# Out:
# 12.498424809175866

# %%
df.salary.quantile(0.25)
# Out:
# 88612.5

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.mean()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15600\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.salary        #does not work if column name contain spaces or dot (eg. No. of Families)
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df['salary']         ##df['No. of Families'] will not work
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
result1 = df['salary']                #series
result1
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
type(result1)
# Out:
# pandas.core.series.Series

# %%
result2 = df[['salary']]                  #Dataframe
result2
# Out:
#     salary
# 0   186960
# 1    93000
# 2   110515
# 3   131205
# 4   104800
# ..     ...
# 73  105450
# 74  104542
# 75  124312
# 76  109954
# 77  109646
#
# [78 rows x 1 columns]

# %%
type(result2)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf = df[['salary', 'service', 'phd']]
newdf
# Out:
#     salary  service  phd
# 0   186960       49   56
# 1    93000        6   12
# 2   110515       20   23
# 3   131205       31   40
# 4   104800       18   20
# ..     ...      ...  ...
# 73  105450       10   18
# 74  104542        6   19
# 75  124312       17   17
# 76  109954       14   28
# 77  109646       15   23
#
# [78 rows x 3 columns]

# %%
df['rank']
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df['discipline'].value_counts()
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# Male      39
# Female    39
# Name: sex, dtype: int64

# %%
df.salary.describe()
#or
df['salary'].describe()
# Out:
# count        78.000000
# mean     108023.782051
# std       28293.661022
# min       57800.000000
# 25%       88612.500000
# 50%      104671.000000
# 75%      126774.750000
# max      186960.000000
# Name: salary, dtype: float64

# %%
df.groupby(['rank']).mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby(['rank']).count()
# Out:
#            discipline  phd  service  sex  salary
# rank
# AssocProf          13   13       13   13      13
# AsstProf           19   19       19   19      19
# Prof               46   46       46   46      46

# %%
df.groupby(['discipline','rank']).count()
# Out:
#                       phd  service  sex  salary
# discipline rank
# A          AssocProf    5        5    5       5
#            AsstProf     8        8    8       8
#            Prof        23       23   23      23
# B          AssocProf    8        8    8       8
#            AsstProf    11       11   11      11
#            Prof        23       23   23      23

# %%
df.groupby(['discipline','rank']).mean()
# Out:
#                             phd    service         salary
# discipline rank
# A          AssocProf  18.800000  15.800000   73959.800000
#            AsstProf    4.375000   2.125000   74450.000000
#            Prof       28.086957  20.434783  111935.695652
# B          AssocProf  12.750000   8.500000  102927.750000
#            AsstProf    5.545455   2.272727   86390.272727
#            Prof       26.043478  22.391304  135313.913043

# %%
df.groupby(['discipline','rank','sex']).mean()
# Out:
#                                    phd    service         salary
# discipline rank      sex
# A          AssocProf Female  18.500000  15.500000   72128.500000
#                      Male    20.000000  17.000000   81285.000000
#            AsstProf  Female   4.833333   2.500000   72933.333333
#                      Male     3.000000   1.000000   79000.000000
#            Prof      Female  26.500000  16.125000  109631.875000
#                      Male    28.933333  22.733333  113164.400000
# B          AssocProf Female  13.500000   8.833333   99435.666667
#                      Male    10.500000   7.500000  113404.000000
#            AsstProf  Female   6.600000   2.600000   84189.800000
#                      Male     4.666667   2.000000   88224.000000
#            Prof      Female  21.500000  17.900000  131836.200000
#                      Male    29.538462  25.846154  137989.076923

# %%
df.groupby('rank')['salary','phd'].mean()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15600\1125438755.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('rank')['salary','phd'].mean()
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
df[df['salary'] > 150000]
#or
df[df.salary > 150000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 27  Prof          A   45       43    Male  155865
# 31  Prof          B   22       21    Male  155750
# 44  Prof          B   23       19  Female  151768
# 72  Prof          B   24       15  Female  161101

# %%
df.shape
# Out:
# (78, 6)

# %%
df.shape[0]
# Out:
# 78

# %%
df.shape[1]
# Out:
# 6

# %%
df[df.salary > 150000].shape
# Out:
# (9, 6)

# %%
df[df.salary > 150000].shape[0]
# Out:
# 9

# %%
newdf = df[(df['sex']=='male') & (df['salary']>150000)]
newdf
# Out:
# Empty DataFrame
# Columns: [rank, discipline, phd, service, sex, salary]
# Index: []

# %%
df[df['rank'] != 'Prof']
# Out:
#          rank discipline  phd  service     sex  salary
# 6   AssocProf          A   20       17    Male   81285
# 12   AsstProf          B    1        0    Male   88000
# 16   AsstProf          B    8        3    Male   75044
# 17   AsstProf          B    4        0    Male   92000
# 20   AsstProf          B    4        4    Male   92000
# 22   AsstProf          A    4        2    Male   73000
# 23   AsstProf          A    2        0    Male   85000
# 28   AsstProf          B    7        2    Male   91300
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 38   AsstProf          B    4        3    Male   91000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# ...

# %%
df[(df['sex'] == 'Female') | (df['service']>10)]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [64 rows x 6 columns]

# %%
df.iloc[3]   #in pandas indexing of dataframe use---  .iloc
# Out:
# rank            Prof
# discipline         A
# phd               40
# service           31
# sex             Male
# salary        131205
# Name: 3, dtype: object

# %%
df.iloc[25:30,]       #rows condition is given
# Out:
#         rank discipline  phd  service   sex  salary
# 25      Prof          B   35       31  Male   99418
# 26      Prof          A   38       19  Male  148750
# 27      Prof          A   45       43  Male  155865
# 28  AsstProf          B    7        2  Male   91300
# 29      Prof          B   21       20  Male  123683

# %%
df.iloc[:, 2:5]      #columns condition is given
# Out:
#     phd  service     sex
# 0    56       49    Male
# 1    12        6    Male
# 2    23       20    Male
# 3    40       31    Male
# 4    20       18    Male
# ..  ...      ...     ...
# 73   18       10  Female
# 74   19        6  Female
# 75   17       17  Female
# 76   28       14  Female
# 77   23       15  Female
#
# [78 rows x 3 columns]

# %%
df.iloc[51:58, 4:6]         #Both condition is given
# Out:
#        sex  salary
# 51  Female  127512
# 52  Female  105000
# 53  Female   73500
# 54  Female   62884
# 55  Female   72500
# 56  Female   77500
# 57  Female   72500

# %%
df.iloc[[12, 25, 46, 8], ]
# Out:
#         rank discipline  phd  service     sex  salary
# 12  AsstProf          B    1        0    Male   88000
# 25      Prof          B   35       31    Male   99418
# 46  AsstProf          B   11        3  Female   74692
# 8       Prof          A   29       19    Male   94350

# %%
df.loc[:, ['rank','salary']]     #only loc
# Out:
#          rank  salary
# 0        Prof  186960
# 1        Prof   93000
# 2        Prof  110515
# 3        Prof  131205
# 4        Prof  104800
# ..        ...     ...
# 73       Prof  105450
# 74  AssocProf  104542
# 75       Prof  124312
# 76       Prof  109954
# 77       Prof  109646
#
# [78 rows x 2 columns]

# %%
df.loc[[24,56,16], ['rank','salary']]
# Out:
#          rank  salary
# 24       Prof   91100
# 56  AssocProf   77500
# 16   AsstProf   75044

# %%
df.iloc[::5]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 5        Prof          A   20       20    Male  122400
# 10       Prof          B   39       33    Male  128250
# 15       Prof          B   17        3    Male  150480
# 20   AsstProf          B    4        4    Male   92000
# 25       Prof          B   35       31    Male   99418
# 30  AssocProf          B    9        7    Male  107008
# 35       Prof          B   28       23    Male  126933
# 40       Prof          A   39       36  Female  137000
# 45       Prof          B   25       25  Female  140096
# 50   AsstProf          B   10        5  Female   97032
# 55   AsstProf          A    2        0  Female   72500
# 60   AsstProf          B    3        3  Female   92000
# 65       Prof          A   36       19  Female  117555
# 70   AsstProf          A    8        3  Female   78500
# 75       Prof          B   17       17  Female  124312

# %%
df.iloc[12:40:4]
# Out:
#         rank discipline  phd  service   sex  salary
# 12  AsstProf          B    1        0  Male   88000
# 16  AsstProf          B    8        3  Male   75044
# 20  AsstProf          B    4        4  Male   92000
# 24      Prof          A   30       23  Male   91100
# 28  AsstProf          B    7        2  Male   91300
# 32      Prof          A   27       19  Male  103275
# 36      Prof          B   45       45  Male  146856

# %%
df.iloc[::-1]
# Out:
#          rank discipline  phd  service     sex  salary
# 77       Prof          A   23       15  Female  109646
# 76       Prof          A   28       14  Female  109954
# 75       Prof          B   17       17  Female  124312
# 74  AssocProf          B   19        6  Female  104542
# 73       Prof          B   18       10  Female  105450
# ..        ...        ...  ...      ...     ...     ...
# 4        Prof          B   20       18    Male  104800
# 3        Prof          A   40       31    Male  131205
# 2        Prof          A   23       20    Male  110515
# 1        Prof          A   12        6    Male   93000
# 0        Prof          B   56       49    Male  186960
#
# [78 rows x 6 columns]

# %%
import pandas as pd
df = pd.read_csv('salaries.csv')
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df['rank'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
marks = [64, 45, 65, 52, 84]
salary = [24000, 61000, 50000, 14000, 19000]

plt.scatter(marks, salary, color ='red')

plt.xlabel('Marks of students')
plt.ylabel('Salaries of students')

plt.title('salary Distribution of students')
# Out:
# Text(0.5, 1.0, 'salary Distribution of students')

# %%
x = [-4, -2, 4, 5, 12]
y = [39, 161, 27, 155, 98]

plt.figure(figsize=(10,6))

plt.plot(x,y)

plt.xlabel('Values of x')
plt.ylabel('Values of y')

plt.title('Demo graph')
plt.suptitle('Learning Data Science', size = 15)

#plitxslim(-20,20)
#plityslim(25,100)
# Out:
# Text(0.5, 0.98, 'Learning Data Science')

# %%
x = list(range(-100,100))
y = [i**3 for i in x]

plt.plot(x,y)

# %%
from math import exp

x = list(range(0,20))
y = [exp(i) for i in x]

plt.plot(x,y)

# %%
from math import log

x = list(range(1,101))
y = [log(i) for i in x]

plt.plot(x,y)

# %%
from math import *

plt.figure(figsize = (16,9))             ## fig size of x & y

x = list(range(-10,11))

y = [i**2 for i in x]
plt.subplot(3,4,1)                        ##figure has 3 rows & 4 columns & this is 1st graph
plt.plot(x,y)
plt.title("Graph of x**2")

y = [i**3 for i in x]
plt.subplot(3,4,10)                       ##figure has 3 rows & 4 columns & this is 10th graph
plt.plot(x,y)
plt.title("Graph of x**3")

y = [sin(i) for i in x]
plt.subplot(3,4,8)
plt.plot(x,y)
plt.title("Graph of sin(i)")
# Out:
# Text(0.5, 1.0, 'Graph of sin(i)')

# %%
data = pd.read_csv("mtcars.csv")
data
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
data.shape
# Out:
# (32, 11)

# %%
data.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
pd.crosstab(data['cyl'], data['gear'])
# Out:
# gear   3  4  5
# cyl
# 4      1  8  2
# 6      2  4  1
# 8     12  0  2

# %%
pd.crosstab(data['cyl'], data['gear']).plot(kind = 'bar')
# Out:
# <Axes: xlabel='cyl'>

# %%
data["gear"].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
data.gear.value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='gear'>

# %%
#scatter plot of 2 variables
plt.scatter(data.mpg, data.qsec, color = 'limegreen')
plt.xlabel("mpg")
plt.ylabel("qsec")
plt.title('mpg vs qsec')
# Out:
# Text(0.5, 1.0, 'mpg vs qsec')

# %%
plt.hist(data['mpg'], edgecolor = 'yellow')
plt.xlabel("No. of cars")
plt.ylabel("mpg")
# Out:
# Text(0, 0.5, 'mpg')

# %%
plt.hist(data['mpg'], facecolor = 'yellow', edgecolor = 'green', bins = 6)
#creats histogrm with 6 bins &colors filled in it
# Out:
# (array([ 4., 10.,  9.,  4.,  1.,  4.]),
#  array([10.4       , 14.31666667, 18.23333333, 22.15      , 26.06666667,
#         29.98333333, 33.9       ]),
#  <BarContainer object of 6 artists>)

# %%
#Boxplot
plt.boxplot(data['mpg'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27abedb9f10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27abedca490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27abedb9c70>],
#  'medians': [<matplotlib.lines.Line2D at 0x27abedca9d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27abedcac70>],
#  'means': []}

# %%
plt.boxplot(data['mpg'], vert = False)
plt.ylabel("MPG")
plt.xlabel("Boxplot")
plt.title("Boxplot")
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
plt.boxplot(data['mpg'], vert = False, notch = True)
plt.ylabel("MPG")
plt.xlabel("Boxplot")
plt.title("Boxplot")
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
import seaborn as sns

#violin plot
sns.violinplot(data['mpg'])  #orient = "v" 'h'         ##sns.violinplot.documentation for more information
# Out:
# <Axes: >

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.shape
# Out:
# (244, 7)

# %%
import pandas as pd

# %%
pd.crosstab(tips['smoker'],tips['sex'])
# Out:
# sex     Male  Female
# smoker
# Yes       60      33
# No        97      54

# %%
pd.crosstab(tips['smoker'],tips['sex']).plot(kind = 'bar')
# Out:
# <Axes: xlabel='smoker'>

# %%
import matplotlib.pyplot as plt

# %%
#strip plot                  a categorical scatterplot using jitter to reduce overplotting.
sns.stripplot(y = 'tip', data = tips, jitter = False)
plt.ylabel('tip ($)')
plt.show()

# %%
sns.stripplot(y = 'tip', data = tips, jitter = True)
plt.ylabel('tip ($)')
plt.show()

# %%
sns.stripplot(x = 'day', y = 'tip', data = tips, jitter = True)
plt.ylabel('tip ($)')
plt.show()

# %%
sns.stripplot(x = 'day', y = 'tip', data = tips, jitter = False)
plt.ylabel('tip ($)')
plt.show()

# %%
sns.stripplot(x = 'day', y = 'tip', data = tips, size = 15, jitter = False)
plt.ylabel('tip ($)')
plt.show()

# %%
#swarm plot              a categorical scatterplot with points adjusted to be non-overlapping.
sns.swarmplot(x = 'day', y = 'tip', data = tips, size = 5)
plt.ylabel('tip ($)')
plt.show()

# %%
tips['sex'].unique()
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Male', 'Female']

# %%
sns.swarmplot(x = 'day', y = 'tip', data = tips, hue ='sex')
plt.ylabel('tip ($)')
plt.show()

# %%
tips['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
sns.swarmplot(x = 'day', y = 'tip', data = tips, hue ='time')
plt.ylabel('tip ($)')
plt.show()

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.swarmplot(x = 'tip', y = 'day', data = tips, hue= 'sex', orient='h')
plt.xlabel('tip ($)')
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
from math import *

plt.figure(figsize = (16,4))             ## fig size of x & y

plt.subplot(1,2,1)
sns.boxplot(x='day', y='tip', data=tips)
plt.ylabel('tip ($)')
plt.title('Boxplot of tips')

plt.subplot(1,2,2)
sns.violinplot(x='day', y='tip', data=tips)
plt.ylabel('tip ($)')
plt.title('Violin plot of tips')

plt.show()

# %%
sns.violinplot(x = 'day', y = 'tip', data = tips, inner=None, color='lightgray')
sns.stripplot(x = 'day', y = 'tip', data = tips, size = 4, jitter = True)
plt.ylabel('tip ($)')
plt.show()

# %%
#Joint plot
sns.jointplot(x ='total_bill', y='tip', data=tips)
plt.show()

# %%
#kernal density plot
sns.jointplot(x ='total_bill', y='tip', data=tips, kind = 'kde')
plt.show()

# %%
sns.pairplot(tips)  #diag_kind = 'kde'
plt.show()

# %%
sns.pairplot(tips, diag_kind = 'kde')
plt.show()

# %%
sns.pairplot(tips, hue ='sex')
plt.show()

# %%
sns.pairplot(tips, hue ='smoker')
plt.show()

# %%
sns.pairplot(tips, hue ='time')
plt.show()

# %%
sns.pairplot(tips, hue ='day')
plt.show()

# %%
data =pd.read_csv('train.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.shape
# Out:
# (891, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.groupby('Survived')['PassengerId'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: PassengerId, dtype: int64

# %%
data.groupby('Sex')['PassengerId'].count()
# Out:
# Sex
# female    314
# male      577
# Name: PassengerId, dtype: int64

# %%
data.groupby(['Survived','Sex'])['PassengerId'].count()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: PassengerId, dtype: int64

# %%
pd.crosstab(data['Survived'], data['Sex'])           ##cross table
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
pd.crosstab(data['Survived'], data['Sex']).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
pd.crosstab(data['Sex'], data['Survived']).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
pd.crosstab(data['Survived'], data['Pclass'])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
pd.crosstab(data['Survived'], data['Pclass']).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
pd.crosstab(data['Pclass'], data['Survived']).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
sns.boxplot(x='Survived', y='Age',  data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.boxplot(x='Sex', y='Survived',  data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.boxplot(x='Sex', y='Age', hue='Survived', data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x='Survived', y='Age', hue='Sex', data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.boxplot(x='Pclass', y='Survived',  data=data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
sns.boxplot(x='Pclass', y='Survived', hue ='Sex', data=data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
sns.barplot(x='SibSp', y='Survived', data=data)
# Out:
# <Axes: xlabel='SibSp', ylabel='Survived'>

# %%
sns.barplot(x='Parch', y='Survived', data=data)
# Out:
# <Axes: xlabel='Parch', ylabel='Survived'>

# %%
data.loc[data['Survived']==1, "Age"]
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 342, dtype: float64

# %%
data.loc[data['Survived']==1, "Age"].isnull()
# Out:
# 1      False
# 2      False
# 3      False
# 8      False
# 9      False
#        ...
# 875    False
# 879    False
# 880    False
# 887    False
# 889    False
# Name: Age, Length: 342, dtype: bool

# %%
data.loc[data['Survived']==1, "Age"].isnull().sum()
# Out:
# 52

# %%
survived=data.loc[data['Survived']==1,'Age']
survived
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 342, dtype: float64

# %%
data.loc[data['Survived']==1, "Age"].dropna()
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 290, dtype: float64

# %%
sns.distplot(survived)
import matplotlib as plt
plt.title("Survived")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15600\1791623706.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(survived)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[138], line 3
#       1 sns.distplot(survived)
#       2 import matplotlib as plt
# ----> 3 plt.title("Survived")
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# ...

# %%
not_survived = data.loc[data['Survived']==0, 'Age'].dropna()
sns.distplot(not_survived)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15600\421274280.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(not_survived)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.pairplot(data.dropna())

# %%
sns.boxplot(y="Survived", x='Fare', data=data, orient='h')
# Out:
# <Axes: xlabel='Fare', ylabel='Survived'>

# %%
data.groupby('Survived')['Fare'].mean()
# Out:
# Survived
# 0    22.117887
# 1    48.395408
# Name: Fare, dtype: float64
